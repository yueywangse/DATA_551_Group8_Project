# %%
# %run src/app.py
# Out:
# C:\Users\yueya\OneDrive\School\MDS\Data 551\Project\DATA_551_Group8_Project\src\app.py:417: DeprecationWarning:
#
# *choropleth_mapbox* is deprecated! Use *choropleth_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
