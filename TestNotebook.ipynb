# %%
# %run src/app.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 app.run(debug=False, host="127.0.0.1", port=8050)
#
# NameError: name 'app' is not defined
